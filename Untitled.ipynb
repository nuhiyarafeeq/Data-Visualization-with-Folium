# %%
import pandas as pd

# %%
a = pd.read_json("Data/Location History.json")

# %%
a.to_csv("Data/jsonToCSV")

# %%
a
# Out:
#                                                 locations
# 0       {'timestampMs': '1507082075674', 'latitudeE7':...
# 1       {'timestampMs': '1507081714453', 'latitudeE7':...
# 2       {'timestampMs': '1507081331168', 'latitudeE7':...
# 3       {'timestampMs': '1507080970091', 'latitudeE7':...
# 4       {'timestampMs': '1507080608977', 'latitudeE7':...
# 5       {'timestampMs': '1507080205185', 'latitudeE7':...
# 6       {'timestampMs': '1507079844156', 'latitudeE7':...
# 7       {'timestampMs': '1507079482936', 'latitudeE7':...
# 8       {'timestampMs': '1507079121936', 'latitudeE7':...
# 9       {'timestampMs': '1507078760912', 'latitudeE7':...
# 10      {'timestampMs': '1507078399810', 'latitudeE7':...
# 11      {'timestampMs': '1507078038773', 'latitudeE7':...
# 12      {'timestampMs': '1507077644056', 'latitudeE7':...
# 13      {'timestampMs': '1507077283058', 'latitudeE7':...
# 14      {'timestampMs': '1507076921895', 'latitudeE7':...
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587883 entries, 0 to 587882
# Data columns (total 1 columns):
# locations    587883 non-null object
# dtypes: object(1)
# memory usage: 4.5+ MB
